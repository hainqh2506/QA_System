# %%
import pandas as pd
import time
import logging
from langchain.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from model_config import load_gemini2
# Khởi tạo logging
logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")
from retrieval import hybrid_retriever, bm25_retriever
# Khởi tạo LangChain Chat Model
llm = load_gemini2()  # Giả sử bạn đã có hàm này để tải mô hình
#db = hybrid_retriever("base")
db = bm25_retriever("raptor")
# Prompt để sinh câu trả lời
template = """
Bạn là chuyên gia trong ngành giáo dục. Nhiệm vụ của bạn là tạo ra các câu trả lời cho phần Câu hỏi bên dưới. 
Hãy tạo câu trả lời phù hợp cho câu hỏi được cung cấp bên dưới. 
## Quan trọng: Các câu trả lời phải được viết bằng tiếng Việt.
Chỉ tạo câu trả lời dựa trên thông tin trong văn bản được cung cấp.

##Dưới đây là những văn bản liên quan:
{context}
##Đây là câu hỏi: 
{question}
##Câu trả lời của bạn là:

Nếu không có đủ thông tin để tạo câu trả lời, trả lời: "Không thể trả lời."
"""

prompt = ChatPromptTemplate.from_template(template)
chain = prompt | llm | StrOutputParser()

# Đọc file Excel đầu vào
input_file = r"D:\DATN\QA_System\eval\testset\output_dataset_out.xlsx"
output_file = r"D:\DATN\QA_System\eval\testset\output_dataset_out.xlsx"
data = pd.read_excel(input_file)

# # Lọc bỏ các dòng có giá trị [] trong cột `filtered_questions`
# data = data[data['filtered_questions'] != '[]']

# Hàm sinh câu trả lời với retry
def generate_answers_with_retry(context, question, retries=5, backoff_factor=2):
    attempt = 0
    while attempt < retries:
        try:
            logging.info(f"Đang tạo câu trả lời cho câu hỏi:")
            result = chain.invoke({"context": context, "question": question})  # Tạo câu trả lời
            return result.strip()
        except Exception as e:
            if "ResourceExhausted" in str(e):
                attempt += 1
                wait_time = backoff_factor ** attempt
                logging.warning(f"Lỗi khi tạo câu trả lời: {e}. Thử lại sau {wait_time} giây...")
                time.sleep(wait_time)
            else:
                logging.error(f"Lỗi không xác định: {e}")
                return "Không thể tạo câu trả lời."
    return "Không thể tạo câu trả lời sau nhiều lần thử lại."

# Sinh câu trả lời cho từng dòng
answers_list = []
for index, row in data.iterrows():

    question = row['Question']
    logging.info(f"Đang xử lý dòng {index+1}/{len(data)}...")
    relevant_docs = db.invoke(question)
    context = "\n\n".join([doc.page_content for doc in relevant_docs])
    # Sinh câu trả lời với retry
    answer = generate_answers_with_retry(context, question)
    answers_list.append(answer)
    
    # Thêm sleep giữa các lần gọi API để không vượt quá giới hạn tốc độ
    time.sleep(4.1)

data['Answerbm25raptor'] = answers_list

# Lưu file kết quả
data.to_excel(output_file, index=False, engine="openpyxl")
logging.info(f"File đã được cập nhật và lưu tại {output_file}")
# Out:
# 2025-01-05 21:14:13,086 - INFO - GET https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/ [status:200 duration:0.704s]
# 2025-01-05 21:14:13,107 - INFO - Đang xử lý dòng 1/90...
# 2025-01-05 21:14:13,289 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.181s]
# 2025-01-05 21:14:13,292 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:14
- INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:19,706 - INFO - Đang xử lý dòng 49/90...
# 2025-01-05 21:18:19,886 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:18:19,888 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:24,683 - INFO - Đang xử lý dòng 50/90...
# 2025-01-05 21:18:24,865 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.181s]
# 2025-01-05 21:18:24,868 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:29,573 - INFO - Đang xử lý dòng 51/90...
# 2025-01-05 21:18:29,754 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:18:29,756 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:39,030 - INFO - Đang xử lý dòng 52/90...
# 2025-01-05 21:18:39,210 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:18:39,212 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:44,089 - INFO - Đang xử lý dòng 53/90...
# 2025-01-05 21:18:44,275 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.185s]
# 2025-01-05 21:18:44,277 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:49,105 - INFO - Đang xử lý dòng 54/90...
# 2025-01-05 21:18:49,280 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.174s]
# 2025-01-05 21:18:49,290 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:54,128 - INFO - Đang xử lý dòng 55/90...
# 2025-01-05 21:18:54,307 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.177s]
# 2025-01-05 21:18:54,310 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:18:59,128 - INFO - Đang xử lý dòng 56/90...
# 2025-01-05 21:18:59,306 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:18:59,309 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:04,122 - INFO - Đang xử lý dòng 57/90...
# 2025-01-05 21:19:04,308 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.185s]
# 2025-01-05 21:19:04,310 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:09,202 - INFO - Đang xử lý dòng 58/90...
# 2025-01-05 21:19:09,383 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.180s]
# 2025-01-05 21:19:09,386 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:14,152 - INFO - Đang xử lý dòng 59/90...
# 2025-01-05 21:19:14,331 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:19:14,334 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:19,130 - INFO - Đang xử lý dòng 60/90...
# 2025-01-05 21:19:19,307 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.177s]
# 2025-01-05 21:19:19,310 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:24,105 - INFO - Đang xử lý dòng 61/90...
# 2025-01-05 21:19:24,280 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.173s]
# 2025-01-05 21:19:24,282 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:29,110 - INFO - Đang xử lý dòng 62/90...
# 2025-01-05 21:19:29,288 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:19:29,290 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:34,104 - INFO - Đang xử lý dòng 63/90...
# 2025-01-05 21:19:34,285 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:19:34,288 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:38,994 - INFO - Đang xử lý dòng 64/90...
# 2025-01-05 21:19:39,193 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.198s]
# 2025-01-05 21:19:39,195 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:43,973 - INFO - Đang xử lý dòng 65/90...
# 2025-01-05 21:19:44,153 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:19:44,155 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:48,943 - INFO - Đang xử lý dòng 66/90...
# 2025-01-05 21:19:49,130 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.186s]
# 2025-01-05 21:19:49,132 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:54,889 - INFO - Đang xử lý dòng 67/90...
# 2025-01-05 21:19:55,062 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.173s]
# 2025-01-05 21:19:55,062 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:19:59,936 - INFO - Đang xử lý dòng 68/90...
# 2025-01-05 21:20:00,116 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:20:00,119 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:00,367 - WARNING - Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2025-01-05 21:20:02,612 - ERROR - Lỗi không xác định: 429 Resource has been exhausted (e.g. check quota).
# 2025-01-05 21:20:06,713 - INFO - Đang xử lý dòng 69/90...
# 2025-01-05 21:20:06,893 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.177s]
# 2025-01-05 21:20:06,895 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:11,680 - INFO - Đang xử lý dòng 70/90...
# 2025-01-05 21:20:11,905 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.223s]
# 2025-01-05 21:20:11,906 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:16,726 - INFO - Đang xử lý dòng 71/90...
# 2025-01-05 21:20:16,906 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:20:16,908 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:21,670 - INFO - Đang xử lý dòng 72/90...
# 2025-01-05 21:20:21,846 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.174s]
# 2025-01-05 21:20:21,848 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:26,977 - INFO - Đang xử lý dòng 73/90...
# 2025-01-05 21:20:27,154 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.175s]
# 2025-01-05 21:20:27,156 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:32,686 - INFO - Đang xử lý dòng 74/90...
# 2025-01-05 21:20:32,866 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:20:32,866 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:37,991 - INFO - Đang xử lý dòng 75/90...
# 2025-01-05 21:20:38,170 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:20:38,173 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:42,939 - INFO - Đang xử lý dòng 76/90...
# 2025-01-05 21:20:43,118 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:20:43,120 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:47,965 - INFO - Đang xử lý dòng 77/90...
# 2025-01-05 21:20:48,147 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.181s]
# 2025-01-05 21:20:48,149 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:52,923 - INFO - Đang xử lý dòng 78/90...
# 2025-01-05 21:20:53,093 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.170s]
# 2025-01-05 21:20:53,101 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:20:53,348 - WARNING - Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised ResourceExhausted: 429 Resource has been exhausted (e.g. check quota)..
# 2025-01-05 21:20:59,970 - INFO - Đang xử lý dòng 79/90...
# 2025-01-05 21:21:00,151 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.180s]
# 2025-01-05 21:21:00,153 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:04,904 - INFO - Đang xử lý dòng 80/90...
# 2025-01-05 21:21:05,083 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:21:05,086 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:09,857 - INFO - Đang xử lý dòng 81/90...
# 2025-01-05 21:21:10,031 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.173s]
# 2025-01-05 21:21:10,033 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:14,972 - INFO - Đang xử lý dòng 82/90...
# 2025-01-05 21:21:15,151 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:21:15,154 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:19,997 - INFO - Đang xử lý dòng 83/90...
# 2025-01-05 21:21:20,180 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.181s]
# 2025-01-05 21:21:20,183 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:25,087 - INFO - Đang xử lý dòng 84/90...
# 2025-01-05 21:21:25,264 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.175s]
# 2025-01-05 21:21:25,266 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:30,612 - INFO - Đang xử lý dòng 85/90...
# 2025-01-05 21:21:30,791 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.178s]
# 2025-01-05 21:21:30,794 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:35,646 - INFO - Đang xử lý dòng 86/90...
# 2025-01-05 21:21:35,828 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.181s]
# 2025-01-05 21:21:35,830 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:40,707 - INFO - Đang xử lý dòng 87/90...
# 2025-01-05 21:21:40,892 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.185s]
# 2025-01-05 21:21:40,895 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:45,686 - INFO - Đang xử lý dòng 88/90...
# 2025-01-05 21:21:45,869 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.181s]
# 2025-01-05 21:21:45,872 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:50,846 - INFO - Đang xử lý dòng 89/90...
# 2025-01-05 21:21:51,024 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.177s]
# 2025-01-05 21:21:51,028 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:21:56,541 - INFO - Đang xử lý dòng 90/90...
# 2025-01-05 21:21:56,721 - INFO - POST https://my-elasticsearch-project-fc9fd1.es.ap-southeast-1.aws.elastic.cloud:443/raptor/_search [status:200 duration:0.179s]
# 2025-01-05 21:21:56,723 - INFO - Đang tạo câu trả lời cho câu hỏi:
# 2025-01-05 21:22:01,808 - INFO - File đã được cập nhật và lưu tại D:\DATN\QA_System\eval\testset\output_dataset_out.xlsx
